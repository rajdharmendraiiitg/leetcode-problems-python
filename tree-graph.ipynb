# %%
### Given a binary tree, find the maximum path sum. The path may start and end at any node in the tree
class BST:
    def __init__(root,data):
        root.data = data
        root.lchild = None
        root.rchild = None
    def insertion(root,data):
        if root.data == None:
            root.data = data
            return
        else:
            if data < root.data:
                if root.lchild: 
                    root.lchild.insertion(data) 
                else:
                    root.lchild = BST(data) 
            else:
                if root.rchild:
                    root.rchild.insertion(data)
                else:
                    root.rchild = BST(data)
    def target_sum(root,target):
        if root.data == None:
            return False
        if root.lchild==None and root.rchild==None and target-root.data == 0:
            return True
        
        #root.lchild.target_sum(target-root.data)
        print("ok",root.data)
        #root.rchild.target_sum(target-root.data)
        return target_sum(root.lchild,target-root.data) or target_sum(root.rchild,target-root.data)
root = BST(None) #BST(10)
node_list = [20,4,30,1,5,6]
for node in node_list:
    root.insertion(node)
print(target_sum(root,10))
# Out:
# ok 20
# ok 4
# ok 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-f66ddb856abb> in <module>
#      34 for node in node_list:
#      35     root.insertion(node)
# ---> 36 print(target_sum(root,10))
#
# <ipython-input-33-cf5768dc8fb2> in target_sum(root, target)
#      29         print("ok",root.data)
#      30         #root.rchild.target_sum(target-root.data)
# ---> 31         return root.lchild.target_sum(target-root.data) or root.rchild.target_sum(target-root.data)
#      32 root = BST(None) #BST(10)
#      33 node_list = [20,4,30,1,5,6]
#
# <ipython-input-36-f66ddb856abb> in target_sum(root, target)
#      29         print("ok",root.data)
#      30         #root.rchild.target_sum(target-root.data)
# ---> 31         return target_sum(root.lchild,target-root.data) or target_sum(root.rchild,target-root.data)
#      32 root = BST(None) #BST(10)
# ...

# %%
### Print all k-sum paths in a binary tree
class Node:
    def __init__(self,data):
        self.data = data
        self.lchild = None
        self.rchild = None
class BST:
    def insertion(self,data):
        self = NODE(data)
        if self.data == None:
            self.data = data
            return
        else:
            if data < self.data:
                if self.lchild: 
                    self.lchild.insertion(data) 
                else:
                    self.lchild = BST(data) 
            else:
                if self.rchild:
                    self.rchild.insertion(data)
                else:
                    self.rchild = BST(data)
    def inOrder(self):
        if self.lchild:
            self.lchild.inOrder()
        print(self.data)
        if self.rchild:
            self.rchild.inOrder()
root = Node() #BST(10)
node_list = [20,4,30,1,5,6]
for node in node_list:
    root.insertion(node)
root.inOrder()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-0794c48ea747> in <module>
#      28         if self.rchild:
#      29             self.rchild.inOrder()
# ---> 30 root = Node() #BST(10)
#      31 node_list = [20,4,30,1,5,6]
#      32 for node in node_list:
#
# TypeError: __init__() missing 1 required positional argument: 'data'

# %%
class Node:
    def __init__(self, key): # self itself node.
        self.left = None
        self.right = None
        self.data = key
class BST:
    def insert(root, key):
        if root is None:
            Node(key)
        else:
            if root.data == key:
                return 
            elif root.data < key:
                #root.right = insert(root.right, key)
                insert(root.right, key)
            else:
                #root.left = insert(root.left, key)
                insert(root.left, key)
        #print(root.data)
        #return root

def target_sum(root,target):
        if root is None:
            return False
        if root.left is None and root.right is None and target-root.data == 0:
            return True
        #print(root.left.data,root.right.data)
        #target_sum(root.left,target-root.data)  
        #target_sum(root.right,target-root.data)
        return target_sum(root.left,target-root.data)  or target_sum(root.right,target-root.data)
def inorder(root):
    if root:
        inorder(root.left)
        print(root.data)
        inorder(root.right)

root = Node(60)
node_list = [50,30,20,40,70,60,80]
for node in node_list:
    BST.insert(root,node)
    #print(root.data)
inorder(r)
#target_sum(root,160)
# Out:
# 20
# 30
# 40
# 50
# 60
# 70
# 80
# 100

# %%
class Node:
    def __init__(self, key): # self itself node.
        self.left = None
        self.right = None
        self.data = key
        #print("node",key)
class BST:
    def insert(root, key):
        if root is None:
            Node(key)
        else:
            if root.data == key:
                return 
            elif root.data < key:
                root.right = insert(root.right, key)
                #insert(root.right, key)
            else:
                root.left = insert(root.left, key)
                #insert(root.left, key)
        #print(root.data)
        return root
    def inOrder(root):
        if root:
            inorder(root.left)
            print(root.data)
            inorder(root.right)
    def target_sum(root,target):
        if root is None:
            return False
        if root.left is None and root.right is None and target-root.data == 0:
            return True
        #print(root.left.data,root.right.data)
        #target_sum(root.left,target-root.data)  
        #target_sum(root.right,target-root.data)
        return target_sum(root.left,target-root.data)  or target_sum(root.right,target-root.data)
root = Node(60)
node_list = [50,30,20,40,70,60,80]
for node in node_list:
    BST.insert(root,node)
#BST.inOrder(root)
print(BST.target_sum(root,160))
# Out:
# 50
# 30
# 20
# ok
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-140-2a53bc68419a> in <module>
#      39     BST.insert(root,node)
#      40 #BST.inOrder(root)
# ---> 41 print(BST.target_sum(root,160))
#
# <ipython-input-140-2a53bc68419a> in target_sum(root, target)
#      33         #target_sum(root.left,target-root.data)
#      34         #target_sum(root.right,target-root.data)
# ---> 35         return target_sum(root.left,target-root.data)  or target_sum(root.right,target-root.data)
#      36 root = Node(60)
#      37 node_list = [50,30,20,40,70,60,80]
#
# <ipython-input-127-11ef71f9a576> in target_sum(root, target)
#      33         #print(target_sum(root.left,target-root.data))
#      34         #target_sum(root.right,target-root.data)
# ---> 35         return target_sum(root.left,target-root.data)  or target_sum(root.right,target-root.data)
# ...

# %%
# Python3

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, x):
#         self.val = x
#         self.left = None
#         self.right = None

class Solution:
    def pathSum(self, root, sum):
        """
        :type root: TreeNode
        :type sum: int
        :rtype: List[List[int]]
        """

        # approach: recursively check children until leaves

        result = []
        self.pathSumRecursive(root, sum, [], result)
        return result

    def pathSumRecursive(self, root, sum, path, result):
        if not root:
            return None

        # at leaf and sum matched
        if not root.left and not root.right and sum == root.val:
            result.append([*path, root.val])
            return None

        path.append(root.val)
        self.pathSumRecursive(root.left, sum - root.val, path, result)
        self.pathSumRecursive(root.right, sum - root.val, path, result)
        path.pop() # remember to revert path

# %%
## Unique Binary Search Trees count and print all
class Solution:
    def numTrees(self, n: int) -> int:
        dp = [0] * (n+1)
        dp[0] = 1
        for i in range(1, n+1):
            for j in range(i):
                dp[i] += dp[j] * dp[i- 1 - j]
        return dp[n]
class Solution:
    def generateTrees(self, n: int) -> List[TreeNode]:
        if n == 0:
            return []
        return self.helper(1, n)


    def helper(self, start, end):
        if start > end: # edge case, see exposition below
            return [None] 
        
        all_trees = [] # list of all unique BSTs
        for curRootVal in range(start, end+1): # generate all roots using list [start, end]
			# recursively get list of subtrees less than curRoot (a BST must have left subtrees less than the root)
            all_left_subtrees = self.helper(start, curRootVal-1)
			
			# recursively get list of subtrees greater than curRoot (a BST must have right subtrees greater than the root)
            all_right_subtrees = self.helper(curRootVal+1, end) 
			
            for left_subtree in all_left_subtrees:   # get each possible left subtree
                for right_subtree in all_right_subtrees: # get each possible right subtree
                    # create root node with each combination of left and right subtrees
                    curRoot = TreeNode(curRootVal) 
                    curRoot.left = left_subtree
                    curRoot.right = right_subtree
					
					# curRoot is now the root of a BST
                    all_trees.append(curRoot)
		
        return all_trees
